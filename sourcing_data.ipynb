# %% [markdown]
# ## Sourcing data from NCBI

# %%
# ./datasets summary taxonomy taxon "Pectobacteriaceae"
P_taxon_id = 1903410

# %% [markdown]
# ## Importing data

# %% [markdown]
# ### Phage accession lookup
# Phage name, ID, NCBI accession

# %%
import pandas as pd
import sys
os_system = sys.platform #recognize operationg system.
if os_system == "win32":
    datasets = "./datasets.exe"
    dataformat = "./dataformat.exe"
else:
    datasets = "./datasets_macOS"
    dataformat = "./dataformat_macOS"

PhagesDB_all = pd.read_csv("PhagesDB_accession_numbers.txt", sep="\t", names=["phage_name", "id", "accession"], header=0)
PhagesDB_all
# Out:
#      phage_name        id  accession
# 0           244  DQ398041  NC_008194
# 1          32HC  KJ028219  NC_023602
# 2          39HC  KJ433973  NC_023603
# 3          40AC  KJ192196  NC_023607
# 4          40BC  KJ433975        NaN
# ...         ...       ...        ...
# 5073      Zorro  MK279896        NaN
# 5074     Zucker  ON645346        NaN
# 5075       Zuko  MN204493        NaN
# 5076       Zulu  MH779517        NaN
# 5077  ZygoTaiga  KM881426        NaN
#
# [5078 rows x 3 columns]

# %% [markdown]
# Only phages with accession numbers

# %%
PDB_acc = PhagesDB_all[PhagesDB_all['accession'].notna()]
PDB_acc
# Out:
#      phage_name        id  accession
# 0           244  DQ398041  NC_008194
# 1          32HC  KJ028219  NC_023602
# 2          39HC  KJ433973  NC_023603
# 3          40AC  KJ192196  NC_023607
# 24      Acadian  JN699007  NC_023701
# ...         ...       ...        ...
# 4917   WIVsmall  KC736071  NC_021334
# 4945       Xeno  KU935728  NC_031243
# 5019       Zaka  KF560334  NC_022985
# 5041     Zemlya  KC700558  NC_021339
# 5066       ZoeJ  KJ510412  NC_024147
#
# [287 rows x 3 columns]

# %%
display(PDB_acc.head(10))
# Out:
#    phage_name        id  accession
# 0         244  DQ398041  NC_008194
# 1        32HC  KJ028219  NC_023602
# 2        39HC  KJ433973  NC_023603
# 3        40AC  KJ192196  NC_023607
# 24    Acadian  JN699007  NC_023701
# 36      Adawi  KF279411  NC_022328
# 42    Adjutor  EU676000  NC_010763
# 51      Adzzy  KF416344  NC_022058
# 54     Aeneas  JQ809703  NC_023723
# 77      Akoma  JN699006  NC_023742

# %%
### Search on NCBI for extra info
import subprocess
import json
from tqdm import tqdm
df_reports = pd.DataFrame()

failed_accessions = []

for acc in tqdm(PDB_acc['accession'], desc="Fetching data from NCBI", unit="acc"):
    #print(acc+".1")
    res = subprocess.run([datasets, "summary", "virus", "genome", "accession", acc+".1"],
                         capture_output=True,   # capture stdout and stderr
                         text=True, 
                         check=True)          # raise an error if the command fails
    # Parse the JSON string
    data = json.loads(res.stdout)
    
    # Check empty data
    if "reports" not in data:
        #print("No reports found in the JSON data.")
        failed_accessions.append(acc)
        continue

    # Convert the 'reports' list to a pandas DataFrame
    if df_reports.empty:
        df_reports = pd.DataFrame(data['reports'])
    else:
        df_reports = pd.concat([df_reports, pd.DataFrame(data['reports'])], ignore_index=True)
display(df_reports)
# Out:
# Fetching data from NCBI: 100%|██████████| 287/287 [02:48<00:00,  1.70acc/s]
#        accession    bioprojects completeness  \
# 0    NC_008194.1  [PRJNA485481]     COMPLETE
# 1    NC_023602.1  [PRJNA485481]     COMPLETE
# 2    NC_023603.1  [PRJNA485481]     COMPLETE
# 3    NC_023607.1  [PRJNA485481]     COMPLETE
# 4    NC_023701.1  [PRJNA485481]     COMPLETE
# ..           ...            ...          ...
# 258  NC_021334.1  [PRJNA485481]     COMPLETE
# 259  NC_031243.1  [PRJNA485481]     COMPLETE
# 260  NC_022985.1  [PRJNA485481]     COMPLETE
# 261  NC_021339.1  [PRJNA485481]     COMPLETE
# 262  NC_024147.1  [PRJNA485481]     COMPLETE
#
#                                                   host  is_annotated  \
# 0    {'lineage': [{'name': 'cellular organisms', 't...          True
# 1    {'lineage': [{'name': 'cellular organisms', 't...          True
# 2    {'lineage': [{'name': 'cellular organisms', 't...          True
# 3    {'lineage': [{'name': 'cellular organisms', 't...          True
# 4    {'lineage': [{'name': 'cellular organisms', 't...          True
# ..                                                 ...           ...
# 258  {'lineage': [{'name': 'cellular organisms', 't...          True
# 259  {'lineage': [{'name': 'cellular organisms', 't...          True
# 260  {'lineage': [{'name': 'cellular organisms', 't...          True
# 261  {'lineage': [{'name': 'cellular organisms', 't...          True
# 262  {'lineage': [{'name': 'cellular organisms', 't...          True
#
#     is_lab_host                         lab_host  length  \
# 0          True          Mycobacterium smegmatis   74483
# 1           NaN                              NaN   50781
# 2           NaN                              NaN   71565
# 3           NaN                              NaN   53396
# 4          True  Mycobacterium smegmatis mc2 155   69864
# ..          ...                              ...     ...
# 258        True  Mycobacterium smegmatis mc2 155   53359
# 259        True  Mycobacterium smegmatis mc2 155   42395
# 260        True  Mycobacterium smegmatis mc2 155   52122
# 261        True            Streptomyces lividans   51077
# 262        True  Mycobacterium smegmatis mc2 155   57315
#
#                         nucleotide  protein_count          release_date  \
# 0    {'sequence_hash': '2974DF27'}            142  2006-06-20T00:00:00Z
# 1     {'sequence_hash': 'CFEA6EA'}             86  2014-03-04T00:00:00Z
# 2    {'sequence_hash': '52C4C232'}            100  2014-03-04T00:00:00Z
# 3    {'sequence_hash': '4EC4E167'}             90  2014-03-04T00:00:00Z
# 4    {'sequence_hash': '4E62B368'}             97  2014-03-11T00:00:00Z
# ..                             ...            ...                   ...
# 258  {'sequence_hash': 'A8A0EF4E'}             83  2013-06-03T00:00:00Z
# 259  {'sequence_hash': '5E5F2E14'}             69  2016-09-27T00:00:00Z
# 260  {'sequence_hash': '910ADD35'}            101  2013-12-04T00:00:00Z
# 261  {'sequence_hash': '7D95B565'}             76  2013-06-03T00:00:00Z
# 262  {'sequence_hash': '7CA1F84F'}             92  2014-05-27T00:00:00Z
#
#     source_database                                          submitter  \
# 0            RefSeq  {'affiliation': 'National Center for Biotechno...
# 1            RefSeq  {'affiliation': 'National Center for Biotechno...
# 2            RefSeq  {'affiliation': 'National Center for Biotechno...
# 3            RefSeq  {'affiliation': 'National Center for Biotechno...
# 4            RefSeq  {'affiliation': 'National Center for Biotechno...
# ..              ...                                                ...
# 258          RefSeq  {'affiliation': 'National Center for Biotechno...
# 259          RefSeq  {'affiliation': 'National Center for Biotechno...
# 260          RefSeq  {'affiliation': 'National Center for Biotechno...
# 261          RefSeq  {'affiliation': 'National Center for Biotechno...
# 262          RefSeq  {'affiliation': 'National Center for Biotechno...
#
#               update_date                                              virus  \
# 0    2023-01-11T00:00:00Z  {'lineage': [{'name': 'Viruses', 'tax_id': 102...
# 1    2023-01-08T00:00:00Z  {'lineage': [{'name': 'Viruses', 'tax_id': 102...
# 2    2023-01-08T00:00:00Z  {'lineage': [{'name': 'Viruses', 'tax_id': 102...
# 3    2023-01-08T00:00:00Z  {'lineage': [{'name': 'Viruses', 'tax_id': 102...
# 4    2023-01-11T00:00:00Z  {'lineage': [{'name': 'Viruses', 'tax_id': 102...
# ..                    ...                                                ...
# 258  2023-01-08T00:00:00Z  {'lineage': [{'name': 'Viruses', 'tax_id': 102...
# 259  2023-01-09T00:00:00Z  {'lineage': [{'name': 'Viruses', 'tax_id': 102...
# 260  2023-01-08T00:00:00Z  {'lineage': [{'name': 'Viruses', 'tax_id': 102...
# 261  2023-01-08T00:00:00Z  {'lineage': [{'name': 'Viruses', 'tax_id': 102...
# 262  2023-01-08T00:00:00Z  {'lineage': [{'name': 'Viruses', 'tax_id': 102...
#
#                                isolate  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4    {'collection_date': '2009-07-01'}
# ..                                 ...
# 258                                NaN
# 259  {'collection_date': '2014-10-01'}
# 260  {'collection_date': '2011-09-29'}
# 261  {'collection_date': '2008-10-30'}
# 262  {'collection_date': '2012-10-01'}
#
#                                               location
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    {'geographic_location': 'USA: Lafayette, LA', ...
# ..                                                 ...
# 258  {'geographic_location': 'China', 'geographic_r...
# 259  {'geographic_location': 'USA: New Haven, CT', ...
# 260  {'geographic_location': 'USA: Los Angeles, CA'...
# 261  {'geographic_location': 'USA: Houston, Texas',...
# 262  {'geographic_location': 'USA', 'geographic_reg...
#
# [263 rows x 17 columns]

# %% [markdown]
# ### Obtaining fasta sequences for each phage
# Using NCBI CLI:

# %%
import zipfile
import os

failed_genomes = []

for acc in tqdm(PDB_acc['accession'], desc="Downloading phage genomes from NCBI", unit="acc"):
    try:
        res = subprocess.run([datasets
        , "download", "virus", "genome", "accession", acc+".1"],
                            capture_output=True,   # capture stdout and stderr
                            text=True, 
                            check=True)          # raise an error if the command fails
    except subprocess.CalledProcessError as e:
        #print(f"Error fetching accession {acc}: {e.stderr}")
        failed_genomes.append(acc)
        continue

    phage_name = PDB_acc.loc[PDB_acc['accession'] == acc, 'phage_name'].values[0]

    if not os.path.exists("ncbi_phage_genomes"):
        os.mkdir("ncbi_phage_genomes")

    with zipfile.ZipFile("ncbi_dataset.zip", "r") as zip_ref:
        file = zip_ref.extract("ncbi_dataset/data/genomic.fna", path=".")
        with open(file, 'r') as f:
            fasta_content = f.read()
            with open(f"ncbi_phage_genomes/{phage_name}.fasta", "w") as output_file:
                output_file.write(fasta_content)
# Out:
# Downloading phage genomes from NCBI: 100%|██████████| 287/287 [03:56<00:00,  1.21acc/s]

# %% [markdown]
# ### Excluding failed accessions

# %%
for acc in failed_genomes:
    print(f"Failed to download genome for accession: {acc}")

for acc in failed_accessions:
    print(f"Failed to fetch summary for accession: {acc}")

print("Filtering")

PDB_acc_success = PDB_acc[~PDB_acc['accession'].isin(failed_accessions + failed_genomes)]
df_reports_success = df_reports[~df_reports['accession'].isin(failed_accessions + failed_genomes)]

PDB_acc_success.to_csv("data_prod/PDB_acc.csv", sep="\t", index=False)
df_reports_success.to_csv("data_prod/NCBI_virus_genome_summary_PDB_phages.csv", index=False)
# Out:
# Failed to download genome for accession: NC_010763
# Failed to download genome for accession: NC_029018
# Failed to download genome for accession: NC_022972
# Failed to download genome for accession: NC_022327
# Failed to download genome for accession: NC_010762
# Failed to download genome for accession: NC_021296
# Failed to download genome for accession: NC_011286
# Failed to download genome for accession: NC_004682
# Failed to download genome for accession: NC_011284
# Failed to download genome for accession: NC_004680
# Failed to download genome for accession: NC_004686
# Failed to download genome for accession: NC_014459
# Failed to download genome for accession: NC_001900
# Failed to download genome for accession: NC_021306
# Failed to download genome for accession: NC_009993
# Failed to download genome for accession: NC_008202
# Failed to download genome for accession: NC_022054
# Failed to download genome for accession: NC_004664
# Failed to download genome for accession: NC_001978
# Failed to download genome for accession: NC_022326
# Failed to download genome for accession: NC_011269
# Failed to download genome for accession: NC_021303
# Failed to download genome for accession: NC_005345
# Failed to download genome for accession: NC_008206
# Failed to fetch summary for accession: NC_010763
# Failed to fetch summary for accession: NC_029018
# Failed to fetch summary for accession: NC_022972
# Failed to fetch summary for accession: NC_022327
# Failed to fetch summary for accession: NC_010762
# Failed to fetch summary for accession: NC_021296
# Failed to fetch summary for accession: NC_011286
# Failed to fetch summary for accession: NC_004682
# Failed to fetch summary for accession: NC_011284
# Failed to fetch summary for accession: NC_004680
# Failed to fetch summary for accession: NC_004686
# Failed to fetch summary for accession: NC_014459
# Failed to fetch summary for accession: NC_001900
# Failed to fetch summary for accession: NC_021306
# Failed to fetch summary for accession: NC_009993
# Failed to fetch summary for accession: NC_008202
# Failed to fetch summary for accession: NC_022054
# Failed to fetch summary for accession: NC_004664
# Failed to fetch summary for accession: NC_001978
# Failed to fetch summary for accession: NC_022326
# Failed to fetch summary for accession: NC_011269
# Failed to fetch summary for accession: NC_021303
# Failed to fetch summary for accession: NC_005345
# Failed to fetch summary for accession: NC_008206
# Filtering
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[19], line 12
#       9 PDB_acc_success = PDB_acc[~PDB_acc['accession'].isin(failed_accessions + failed_genomes)]
#      10 df_reports_success = df_reports[~df_reports['accession'].isin(failed_accessions + failed_genomes)]
# ---> 12 PDB_acc_success.to_csv("data_prod/PDB_acc.csv", sep="\t", index=False)
#      13 df_reports_success.to_csv("data_prod/NCBI_virus_genome_summary_PDB_phages.csv", index=False)
#
# File c:\Users\asbjo\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\asbjo\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:3986, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3975 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3977 formatter = DataFrameFormatter(
#    3978     frame=df,
#    3979     header=header,
#    (...)
#    3983     decimal=decimal,
#    3984 )
# -> 3986 return DataFrameRenderer(formatter).to_csv(
#    3987     path_or_buf,
#    3988     lineterminator=lineterminator,
#    3989     sep=sep,
#    3990     encoding=encoding,
#    3991     errors=errors,
#    3992     compression=compression,
#    3993     quoting=quoting,
#    3994     columns=columns,
#    3995     index_label=index_label,
#    3996     mode=mode,
#    3997     chunksize=chunksize,
#    3998     quotechar=quotechar,
#    3999     date_format=date_format,
#    4000     doublequote=doublequote,
#    4001     escapechar=escapechar,
#    4002     storage_options=storage_options,
#    4003 )
#
# File c:\Users\asbjo\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\asbjo\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File c:\Users\asbjo\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File c:\Users\asbjo\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'data_prod'

# %% [markdown]
# ### Phages against clusters
# Clusters identify which bacteria each phage can infect

# %%
PDB_phage_cluster = pd.read_csv("PhagesDB_Data.txt", sep="\t", header=0)
PDB_phage_cluster
# Out:
#      Phage Name Cluster Subcluster
# 0          20ES       A         A2
# 1           244       E        NaN
# 2          32HC       Z        NaN
# 3          39HC       B         B6
# 4          40AC       A        A17
# ...         ...     ...        ...
# 5573      Zorro      AK        NaN
# 5574     Zucker      FN        NaN
# 5575       Zuko      BR        NaN
# 5576       Zulu       A         A6
# 5577  ZygoTaiga       C         C1
#
# [5578 rows x 3 columns]
